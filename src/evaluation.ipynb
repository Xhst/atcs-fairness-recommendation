# %%
from evaluation import Evaluation
from dataset import Dataset
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ratings_df = pd.read_csv(Dataset.get_dataset_path() + '/movielens-edu/ratings.csv')

ds = Dataset(ratings_df)

training_set, test_set = Evaluation.split_dataset(ds.ratings_df, 0.5)

# %%
similarities = ['pcc', 'jaccard', 'cosine', 'acosine', 'manhattan', 'euclidean', 'chebyshev', 'acosine_jaccard']
k_range = np.arange(start=5, stop=55, step=5)
mae_points, mrse_points = Evaluation.evaluate_similarities(similarities, training_set, test_set, k_range)

# %%
x = k_range
for sim in similarities:
    plt.plot(x, mae_points[sim], '*-')
plt.ylabel('MAE')
plt.xlabel('Neighbor size')
#plt.ylim((0.7, 1))
plt.xticks(x)
plt.legend(similarities)
plt.show()

# %%
x = k_range
for sim in similarities:
    plt.plot(x, mrse_points[sim], '*-')
plt.ylabel('RMSE')
plt.xlabel('Neighbor size')
#plt.ylim((0.7, 1))
plt.xticks(x)
plt.legend(similarities)
plt.show()
