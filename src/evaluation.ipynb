# %%
from evaluation import Evaluation
from dataset import Dataset
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from evaluation import Evaluation
#       2 from dataset import Dataset
# ----> 3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
ratings_df = pd.read_csv(Dataset.get_dataset_path() + 'ratings.csv')
ds = Dataset(ratings_df)

training_set, test_set = Evaluation.split_dataset(ds.ratings_df, 0.7)

# %%
similarities = ['jaccard', 'pcc', 'pcc_jaccard']

mae_points, mrse_points = Evaluation.evaluate_similarities(similarities, )
# Out:
# Testing similarity jaccard with k=5 on test split 0
# Testing similarity pcc with k=5 on test split 0
# Testing similarity pcc_jaccard with k=5 on test split 0
# Testing similarity jaccard with k=10 on test split 1
# Testing similarity pcc with k=10 on test split 1
# Testing similarity jaccard with k=15 on test split 2
# Testing similarity pcc_jaccard with k=10 on test split 1
# Testing similarity jaccard with k=20 on test split 3
# Testing similarity pcc with k=15 on test split 2
# Testing similarity jaccard with k=25 on test split 4
# Testing similarity pcc_jaccard with k=15 on test split 2
# Testing similarity pcc with k=20 on test split 3
# Testing similarity jaccard with k=30 on test split 0
# Testing similarity jaccard with k=35 on test split 1
# Testing similarity pcc with k=25 on test split 4
# Testing similarity pcc_jaccard with k=20 on test split 3
# Testing similarity jaccard with k=40 on test split 2
# Testing similarity jaccard with k=45 on test split 3
# Testing similarity pcc with k=30 on test split 0
# Testing similarity pcc_jaccard with k=25 on test split 4
# Testing similarity jaccard with k=50 on test split 4
# Testing similarity pcc with k=35 on test split 1
# Testing similarity pcc_jaccard with k=30 on test split 0
# Testing similarity pcc with k=40 on test split 2
# Testing similarity pcc with k=45 on test split 3
# Testing similarity pcc_jaccard with k=35 on test split 1
# Testing similarity pcc with k=50 on test split 4
# Testing similarity pcc_jaccard with k=40 on test split 2
# Testing similarity pcc_jaccard with k=45 on test split 3
# Testing similarity pcc_jaccard with k=50 on test split 4

# %%
x = np.arange(5, 55, 5)
for sim in similarities:
    plt.plot(x, mae_points[sim], '*-')
plt.ylabel('MAE')
plt.xlabel('Neighbor size')
#plt.ylim((0.7, 1))
plt.xticks(x)
plt.legend(similarities)
plt.show()

# %%
x = np.arange(5, 55, 5)
for sim in similarities:
    plt.plot(x, mrse_points[sim], '*-')
plt.ylabel('RMSE')
plt.xlabel('Neighbor size')
#plt.ylim((0.7, 1))
plt.xticks(x)
plt.legend(similarities)
plt.show()
